# %%
f = open('abc.txt', 'w')
print('file name:',f.name)
print('file mode:',f.mode)
print(f.readable())
print(f.writable())
print(f.closed)
f.close()
print(f.closed)
# Out:
# file name: abc.txt
# file mode: w
# False
# True
# False
# True

# %%
with open("abc.txt","r") as file:
    content=file.read()
print(content)
# Out:
# aditya degree college
# kainada
# niharika

# %%
with open("example.txt","r") as file:#syntax for with statement
    data=file.read()

# %%
with open("abc.txt","r") as file:
    content=file.read(10)
print(content)
# Out:
# aditya deg

# %%
with open("abc.txt","r") as file:
    content=file.readline()
print(content)
# Out:
# aditya degree college

# %%
with open("abc.txt","r") as file:
    content=file.readlines()
print(content)
# Out:
# ['aditya degree college\n', 'kainada\n', 'niharika']

# %%
with open("abc.txt","w") as file:
    file.write("aditya degree college")

# %%
i=["aditya degree college\n","kakinada\n","andhra pradesh"]
with open("abc.txt","w") as file:
          file.writelines(i)

# %%
with open("abc.txt","a") as file:
    file.write("533430")

# %%
#writing to a csv file
import csv
with open("aaaaaaa.csv","w",newline="") as file:
    writer=csv.writer(file)
    writer.writerow(["name", "age", "city"])
    writer.writerow(["niha", "20", "kkd"])

# %% [markdown]
# ###
